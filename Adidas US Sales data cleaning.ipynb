# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Downloads/Adidas US Sales Datasets.xlsx")

# %%
df.head(20)
# Out:
#        Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1   Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2   Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3   Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4   Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# 5   Foot Locker      1185732   2020-01-06  Northeast  New York  New York
# 6   Foot Locker      1185732   2020-01-07  Northeast  New York  New York
# 7   Foot Locker      1185732   2020-01-08  Northeast  New York  New York
# 8   Foot Locker      1185732   2020-01-21  Northeast  New York  New York
# 9   Foot Locker      1185732   2020-01-22  Northeast  New York  New York
# 10  Foot Locker      1185732   2020-01-23  Northeast  New York  New York
# 11  Foot Locker      1185732   2020-01-24  Northeast  New York  New York
# ...

# %%
df.tail(20)
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 9628  Foot Locker      1185732   2021-11-18  Northeast  New Hampshire
# 9629  Foot Locker      1185732   2021-11-18  Northeast  New Hampshire
# 9630  Foot Locker      1185732   2021-11-18  Northeast  New Hampshire
# 9631  Foot Locker      1185732   2021-11-18  Northeast  New Hampshire
# 9632  Foot Locker      1185732   2021-11-18  Northeast  New Hampshire
# 9633  Foot Locker      1185732   2021-12-17  Northeast  New Hampshire
# 9634  Foot Locker      1185732   2021-12-17  Northeast  New Hampshire
# 9635  Foot Locker      1185732   2021-12-17  Northeast  New Hampshire
# 9636  Foot Locker      1185732   2021-12-17  Northeast  New Hampshire
# 9637  Foot Locker      1185732   2021-12-17  Northeast  New Hampshire
# 9638  Foot Locker      1185732   2021-12-17  Northeast  New Hampshire
# 9639  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# ...

# %%
df.isnull()
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0           True        True       False        True        True        True
# 1           True        True        True        True        True        True
# 2           True        True        True        True        True        True
# 3           True       False       False       False       False       False
# 4           True       False       False       False       False       False
# ...          ...         ...         ...         ...         ...         ...
# 9647        True       False       False       False       False       False
# 9648        True       False       False       False       False       False
# 9649        True       False       False       False       False       False
# 9650        True       False       False       False       False       False
# 9651        True       False       False       False       False       False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     9652
# Unnamed: 1        3
# Unnamed: 2        2
# Unnamed: 3        3
# Unnamed: 4        3
# Unnamed: 5        3
# Unnamed: 6        3
# Unnamed: 7        3
# Unnamed: 8        3
# Unnamed: 9        3
# Unnamed: 10       3
# Unnamed: 11       3
# Unnamed: 12       3
# Unnamed: 13       3
# dtype: int64

# %%
df_raw = pd.read_excel("Downloads/Adidas US Sales Datasets.xlsx", header=None)
df_raw.head(10)
# Out:
#    0            1                      2                    3          4   \
# 0 NaN          NaN                    NaN                  NaN        NaN
# 1 NaN          NaN  Adidas Sales Database                  NaN        NaN
# 2 NaN          NaN                    NaN                  NaN        NaN
# 3 NaN          NaN                    NaN                  NaN        NaN
# 4 NaN     Retailer            Retailer ID         Invoice Date     Region
# 5 NaN  Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# 6 NaN  Foot Locker                1185732  2020-01-02 00:00:00  Northeast
# 7 NaN  Foot Locker                1185732  2020-01-03 00:00:00  Northeast
# 8 NaN  Foot Locker                1185732  2020-01-04 00:00:00  Northeast
# 9 NaN  Foot Locker                1185732  2020-01-05 00:00:00  Northeast
#
#          5         6                          7               8           9   \
# ...

# %%
df_raw.head(20)
# Out:
#     0            1                      2                    3          4   \
# 0  NaN          NaN                    NaN                  NaN        NaN
# 1  NaN          NaN  Adidas Sales Database                  NaN        NaN
# 2  NaN          NaN                    NaN                  NaN        NaN
# 3  NaN          NaN                    NaN                  NaN        NaN
# 4  NaN     Retailer            Retailer ID         Invoice Date     Region
# 5  NaN  Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# 6  NaN  Foot Locker                1185732  2020-01-02 00:00:00  Northeast
# 7  NaN  Foot Locker                1185732  2020-01-03 00:00:00  Northeast
# 8  NaN  Foot Locker                1185732  2020-01-04 00:00:00  Northeast
# 9  NaN  Foot Locker                1185732  2020-01-05 00:00:00  Northeast
# 10 NaN  Foot Locker                1185732  2020-01-06 00:00:00  Northeast
# ...

# %%
df=pd.read_excel("Downloads/Adidas US Sales Datasets.xlsx",header=4)

# %%
print(df.columns)
df.head(10)
# Out:
# Index(['Unnamed: 0', 'Retailer', 'Retailer ID', 'Invoice Date', 'Region',
#        'State', 'City', 'Product', 'Price per Unit', 'Units Sold',
#        'Total Sales', 'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')
#    Unnamed: 0     Retailer  Retailer ID Invoice Date     Region     State  \
# 0         NaN  Foot Locker      1185732   2020-01-01  Northeast  New York
# 1         NaN  Foot Locker      1185732   2020-01-02  Northeast  New York
# 2         NaN  Foot Locker      1185732   2020-01-03  Northeast  New York
# 3         NaN  Foot Locker      1185732   2020-01-04  Northeast  New York
# 4         NaN  Foot Locker      1185732   2020-01-05  Northeast  New York
# 5         NaN  Foot Locker      1185732   2020-01-06  Northeast  New York
# 6         NaN  Foot Locker      1185732   2020-01-07  Northeast  New York
# 7         NaN  Foot Locker      1185732   2020-01-08  Northeast  New York
# ...

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
print(df.columns)
df.head(10)
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# 5  Foot Locker      1185732   2020-01-06  Northeast  New York  New York
# 6  Foot Locker      1185732   2020-01-07  Northeast  New York  New York
# 7  Foot Locker      1185732   2020-01-08  Northeast  New York  New York
# 8  Foot Locker      1185732   2020-01-21  Northeast  New York  New York
# ...

# %%
df.isnull()
# Out:
#       Retailer  Retailer ID  Invoice Date  Region  State   City  Product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 9643     False        False         False   False  False  False    False
# 9644     False        False         False   False  False  False    False
# 9645     False        False         False   False  False  False    False
# 9646     False        False         False   False  False  False    False
# 9647     False        False         False   False  False  False    False
#
#       Price per Unit  Units Sold  Total Sales  Operating Profit  \
# ...

# %%
df.describe()
# Out:
#         Retailer ID                   Invoice Date  Price per Unit  \
# count  9.648000e+03                           9648     9648.000000
# mean   1.173850e+06  2021-05-10 15:20:44.776119296       45.216625
# min    1.128299e+06            2020-01-01 00:00:00        7.000000
# 25%    1.185732e+06            2021-02-17 00:00:00       35.000000
# 50%    1.185732e+06            2021-06-04 00:00:00       45.000000
# 75%    1.185732e+06            2021-09-16 00:00:00       55.000000
# max    1.197831e+06            2021-12-31 00:00:00      110.000000
# std    2.636038e+04                            NaN       14.705397
#
#         Units Sold    Total Sales  Operating Profit  Operating Margin
# count  9648.000000    9648.000000       9648.000000       9648.000000
# mean    256.930037   93273.437500      34425.244761          0.422991
# min       0.000000       0.000000          0.000000          0.100000
# 25%     106.000000    4254.500000       1921.752500          0.350000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %%
df.to_csv("Downloads/Adidas_US_Sales_Cleaned.csv", index=False)
